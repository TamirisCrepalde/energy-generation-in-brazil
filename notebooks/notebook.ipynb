# %% [markdown]
# # Brazil's Energy Generation
#
# This notebook presents an exploration about the Brazil's energy generation in the years XXX and XXXX.
#
# The data used in this analysis can be found at [Operador Nacional do Sistema Elétrico](http://www.ons.org.br/Paginas/resultados-da-operacao/historico-da-operacao/geracao_energia.aspx). The source doesn't presents an description for the features, so we'll try to understand it thinking about the context.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## First impressions

# %%
df = pd.read_csv("../data/raw/Geração_de_Energia_Subsistema_Full_Data_data.csv")
df.head()
# Out:
# /home/tamiris/Documentos/Work/2021/ota-searches/dsc-notebooks/ota_searchs/ota/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (9,10,16,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           id_subsistema Modalidade de Operação nom_tipousinasite  \
# 0  Sudeste/Centro-Oeste     Conjunto de Usinas           Térmica
# 1              Nordeste     Conjunto de Usinas            Eólica
# 2                   Sul     Conjunto de Usinas      Hidrelétrica
# 3              Nordeste     Conjunto de Usinas            Eólica
# 4              Nordeste     Conjunto de Usinas            Eólica
#
#    Período Verifica GE Cps 1  Val Geraenergiaconmwmed  Cod Aneel  \
# 0                       True               169.841625        NaN
# 1                       True                 0.000000        NaN
# 2                       True                24.200000        NaN
# 3                       True                27.420583        NaN
# 4                       True                37.047417        NaN
#
#    Cod Aneel - Divisão 4  Cod Nucleoaneel  \
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
#
#    cod_modalidadeoperusiconj (tb usina)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   cod_nucleoaneel (tb_referenciacegusina (Conjunto))  ...  \
# 0                                           000009-J  ...
# 1                                           000023-J  ...
# 2                                           000036-J  ...
# 3                                           000015-J  ...
# 4                                           000028-J  ...
#
#   cod_nucleoaneel (tb_referenciacegusina1 (PrevCarga))           Din Instante  \
# 0                                                NaN    9/30/2019 12:00:00 AM
# 1                                                NaN    10/1/2019 12:00:00 AM
# 2                                                NaN    10/1/2019 12:00:00 AM
# 3                                                NaN    10/1/2019 12:00:00 AM
# 4                                                NaN    10/1/2019 12:00:00 AM
#
#    Din Instante GE Cps 1           dsc_estado Período Exibido GE  \
# 0  9/30/2019 12:00:00 AM                GOIAS                  4
# 1  10/1/2019 12:00:00 AM           PERNAMBUCO                  4
# 2  10/1/2019 12:00:00 AM    RIO GRANDE DO SUL                  4
# 3  10/1/2019 12:00:00 AM                BAHIA                  4
# 4  10/1/2019 12:00:00 AM  RIO GRANDE DO NORTE                  4
#
#    Qtd Din Instante GE Cps 1          Table Name Selecione Tipo de GE Cps 1  \
# 0      9/30/2019 12:00:00 AM  gr_diconjuntousina                      170.0
# 1      10/1/2019 12:00:00 AM  gr_diconjuntousina                        0.0
# 2      10/1/2019 12:00:00 AM  gr_diconjuntousina                       24.0
# 3      10/1/2019 12:00:00 AM  gr_diconjuntousina                       27.0
# 4      10/1/2019 12:00:00 AM  gr_diconjuntousina                       37.0
#
#   Val Geraenergiacongwh  Zero
# 0              4.076199     0
# 1              0.000000     0
# 2              0.580800     0
# 3              0.658094     0
# 4              0.889138     0
#
# [5 rows x 21 columns]

# %% [markdown]
# The dataset has a lot of columns with information that doesn't bring useful information, so first we can select a set of columns to start analyze. To decide which columns to choose, we can make an describe.
#
# Above we can see NaN columns  like `Cod Aneel` and `Cod Aneel - Divisão 4`, so this columns will not be selected. There are also columns with only one unique value like `Período Verifica GE Cps 1` and `Zero`.
#
# Interesting columns:
# - `id_subsistema`: unique identifier of the subsystem of generation
# - `Modalidade de Operação`: mode of operation
# - `nom_tipousinasite`: name of types of power plants
# - `Val Geraenergiaconmwmed`: value of energy generation average MW
# - `Din Instante`: probably the moment of measure
# - `dsc_estado`: name of the state
# - `Val Geraenergiacongwh`: value of energy generation GWh

# %%
df.describe(include='all')
# Out:
#                id_subsistema Modalidade de Operação nom_tipousinasite  \
# count                2460642                2460642           2460642
# unique                     4                      7                 5
# top     Sudeste/Centro-Oeste                 Tipo I      Hidrelétrica
# freq                 1214893                1554277           1260820
# mean                     NaN                    NaN               NaN
# std                      NaN                    NaN               NaN
# min                      NaN                    NaN               NaN
# 25%                      NaN                    NaN               NaN
# 50%                      NaN                    NaN               NaN
# 75%                      NaN                    NaN               NaN
# max                      NaN                    NaN               NaN
#
#        Período Verifica GE Cps 1  Val Geraenergiaconmwmed  Cod Aneel  \
# count                    2460642             2.460642e+06        0.0
# unique                         1                      NaN        NaN
# top                         True                      NaN        NaN
# freq                     2460642                      NaN        NaN
# mean                         NaN             1.809783e+02        NaN
# std                          NaN             5.246914e+02        NaN
# min                          NaN            -2.957958e+01        NaN
# 25%                          NaN             4.241986e+00        NaN
# 50%                          NaN             3.893292e+01        NaN
# 75%                          NaN             1.303212e+02        NaN
# max                          NaN             1.090265e+04        NaN
#
#         Cod Aneel - Divisão 4  Cod Nucleoaneel  \
# count                     0.0              0.0
# unique                    NaN              NaN
# top                       NaN              NaN
# freq                      NaN              NaN
# mean                      NaN              NaN
# std                       NaN              NaN
# min                       NaN              NaN
# 25%                       NaN              NaN
# 50%                       NaN              NaN
# 75%                       NaN              NaN
# max                       NaN              NaN
#
#         cod_modalidadeoperusiconj (tb usina)  \
# count                                    0.0
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#        cod_nucleoaneel (tb_referenciacegusina (Conjunto))  ...  \
# count                                              276329  ...
# unique                                                176  ...
# top                                              000003-J  ...
# freq                                                 3445  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#        cod_nucleoaneel (tb_referenciacegusina1 (PrevCarga))  \
# count                                                 0.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                  Din Instante  Din Instante GE Cps 1 dsc_estado  \
# count                 2460642                2460642    2460642
# unique                   8414                   8414         27
# top     3/10/2021 12:00:00 AM  3/10/2021 12:00:00 AM  SAO PAULO
# freq                      587                    587     349510
# mean                      NaN                    NaN        NaN
# std                       NaN                    NaN        NaN
# min                       NaN                    NaN        NaN
# 25%                       NaN                    NaN        NaN
# 50%                       NaN                    NaN        NaN
# 75%                       NaN                    NaN        NaN
# max                       NaN                    NaN        NaN
#
#        Período Exibido GE  Qtd Din Instante GE Cps 1  Table Name  \
# count           2460642.0                     741428     2460642
# unique                NaN                       1461           3
# top                   NaN      3/10/2021 12:00:00 AM  gr_diusina
# freq                  NaN                        587     2024108
# mean                  4.0                        NaN         NaN
# std                   0.0                        NaN         NaN
# min                   4.0                        NaN         NaN
# 25%                   4.0                        NaN         NaN
# 50%                   4.0                        NaN         NaN
# 75%                   4.0                        NaN         NaN
# max                   4.0                        NaN         NaN
#
#        Selecione Tipo de GE Cps 1  Val Geraenergiacongwh       Zero
# count                    741428.0           2.460642e+06  2460642.0
# unique                     6031.0                    NaN        NaN
# top                           0.0                    NaN        NaN
# freq                      99512.0                    NaN        NaN
# mean                          NaN           4.343479e+00        0.0
# std                           NaN           1.259259e+01        0.0
# min                           NaN          -7.099100e-01        0.0
# 25%                           NaN           1.018077e-01        0.0
# 50%                           NaN           9.343900e-01        0.0
# 75%                           NaN           3.127708e+00        0.0
# max                           NaN           2.616636e+02        0.0
#
# [11 rows x 21 columns]

# %% [markdown]
# Selecting the columns:

# %%
df = df[[
    'id_subsistema', 
    'Modalidade de Operação', 
    'nom_tipousinasite', 
    'Val Geraenergiaconmwmed', 
    'Din Instante', 
    'dsc_estado', 
    'Val Geraenergiacongwh'
    ]]
df.head()
# Out:
#           id_subsistema Modalidade de Operação nom_tipousinasite  \
# 0  Sudeste/Centro-Oeste     Conjunto de Usinas           Térmica
# 1              Nordeste     Conjunto de Usinas            Eólica
# 2                   Sul     Conjunto de Usinas      Hidrelétrica
# 3              Nordeste     Conjunto de Usinas            Eólica
# 4              Nordeste     Conjunto de Usinas            Eólica
#
#    Val Geraenergiaconmwmed           Din Instante           dsc_estado  \
# 0               169.841625  9/30/2019 12:00:00 AM                GOIAS
# 1                 0.000000  10/1/2019 12:00:00 AM           PERNAMBUCO
# 2                24.200000  10/1/2019 12:00:00 AM    RIO GRANDE DO SUL
# 3                27.420583  10/1/2019 12:00:00 AM                BAHIA
# 4                37.047417  10/1/2019 12:00:00 AM  RIO GRANDE DO NORTE
#
#    Val Geraenergiacongwh
# 0               4.076199
# 1               0.000000
# 2               0.580800
# 3               0.658094
# 4               0.889138

# %% [markdown]
# Now we can focus in just some meaningful features.
#
# For the `describe` below, we can see all our data is complete, there is no NaN values. First impressions:
# - `id_subsistema`: there are 4 distinct subsystems, the most frequent is `Sudeste/Centro-Oeste` and its frequency is almost 50% of the cases
# - `Modalidade de Operação`: there are 7 types of operation modes, the most frequent is `Tipo I` and its represents more than 50% of the data
# - `nom_tipousinasite`: there are 5 types of power plants, the most frequent is `Hidrelétrica` and its represents also more than 50% of the data
# - `Val Geraenergiaconmwmed`:
# - `Din Instante`:
# - `dsc_estado`:
# - `dsc_estado`:

# %%
df.describe(include='all')
# Out:
#                id_subsistema Modalidade de Operação nom_tipousinasite  \
# count                2460642                2460642           2460642
# unique                     4                      7                 5
# top     Sudeste/Centro-Oeste                 Tipo I      Hidrelétrica
# freq                 1214893                1554277           1260820
# mean                     NaN                    NaN               NaN
# std                      NaN                    NaN               NaN
# min                      NaN                    NaN               NaN
# 25%                      NaN                    NaN               NaN
# 50%                      NaN                    NaN               NaN
# 75%                      NaN                    NaN               NaN
# max                      NaN                    NaN               NaN
#
#         Val Geraenergiaconmwmed           Din Instante dsc_estado  \
# count              2.460642e+06                2460642    2460642
# unique                      NaN                   8414         27
# top                         NaN  3/10/2021 12:00:00 AM  SAO PAULO
# freq                        NaN                    587     349510
# mean               1.809783e+02                    NaN        NaN
# std                5.246914e+02                    NaN        NaN
# min               -2.957958e+01                    NaN        NaN
# 25%                4.241986e+00                    NaN        NaN
# 50%                3.893292e+01                    NaN        NaN
# 75%                1.303212e+02                    NaN        NaN
# max                1.090265e+04                    NaN        NaN
#
#         Val Geraenergiacongwh
# count            2.460642e+06
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean             4.343479e+00
# std              1.259259e+01
# min             -7.099100e-01
# 25%              1.018077e-01
# 50%              9.343900e-01
# 75%              3.127708e+00
# max              2.616636e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460642 entries, 0 to 2460641
# Data columns (total 7 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   id_subsistema            object
#  1   Modalidade de Operação   object
#  2   nom_tipousinasite        object
#  3   Val Geraenergiaconmwmed  float64
#  4   Din Instante             object
#  5   dsc_estado               object
#  6   Val Geraenergiacongwh    float64
# dtypes: float64(2), object(5)
# memory usage: 131.4+ MB
